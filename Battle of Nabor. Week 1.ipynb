# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 1) #

# %% [markdown]
# # Open a Coffee shop In NuwaraEliya - Sri Lanka

# %%
from IPython.display import Image as IPythonImage
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw
import requests
url ='http://dnatatravel.in/wp-content/uploads/2017/07/olanka-travels-sri-lanka-tour-nuwara-eliya-3.jpg'
im =Image.open(requests.get(url, stream=True).raw)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x500 at 0x29375727CC0>

# %% [markdown]
# # Introduction

# %% [markdown]
# *NuwaraEliya is one of famous local and international tourist destination located in Sri Lanka. The city is famous because of its unique natural beauty and amazing weather condition. NuwaraEliya famous for verity of restaurants (local and international) which serves domestic and international cousins. Because of cold weather, most of tourist prefer to have cup of hot coffee while enjoying their vacation*.

# %% [markdown]
# # Business Problem

# %% [markdown]
# *Even though NuwaraEliya Town famous for different type of restaurant , it does not have world standard (I.e. Starbucks) coffee shop which can provide world class coffee experience to visitors. Most of road side coffee shops do not have proper hygiene level or equipped with require machinery for coffee preparation. objective of this project is to analysis best location to start a world class coffee shop in NuwaraEliya Sri Lanka . Using data science methodologies such as clustering, this project aims to provide suggestions for locations in NuwaraEliya city to start a coffee shop*.

# %% [markdown]
# # Target Audiences

# %% [markdown]
# 1. Local and International Investors,
# 2. Existing hotels and restaurants owners

# %% [markdown]
# # Data

# %% [markdown]
# ## *We Need following data to resolve the problem*

# %% [markdown]
# 1. List of neighborhoods in NwaraEliya. This defines the scope of the project which will be confined to the city of NuwaEliya, the best tourist destination  of the country of Sri Lanka in South Asia
# 2. Latitude and Longitude coordinates of above neighborhoods in order to plot the maps and obtain venue data
# 3. Venue data, particularly data of coffee shop. This can be used to perform clustering of neighborhoods.

# %% [markdown]
# ## Sources of Data

# %% [markdown]
# The yamu page (https://www.yamu.lk/place/coffee-bar/review-46910) contains a list of existing coffee shops in Nuwaerliya along with customer reviews. We will be using web scraping techniques to extract data from the yamu page with the help of Python and beautifulsoup packages.
# Foursquare API to get venue data for above neighborhoods. Foursquare has one of the largest data base of over 100 million places and is used by over 150,000 developers across the world. Foursquare API will provide many categories of venue data and we will be focussing on coffee shop in order for us to solve the problem that has been put forward.
